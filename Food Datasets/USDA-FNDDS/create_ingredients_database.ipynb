# %% [markdown]
# **Author :  Ong Cheng Kei TP055620** <br>
# **Description :**
# <br>This file contains code to preprocess the USDA-FNDDS Nutrients Database.<br>The input file used is 2017-2018 FNDDS At A Glance - FNDDS Nutrient Values.xlsx and the output contains two files which are cleaned_fndds_nutrient_values.csv (tab separated) and cleaned_food_category.txt

# %%
from pprint import pprint

import pandas as pd

# %%
FNDDS_NUTRIENT_VALUES_PATH = (
    "./2017-2018 FNDDS At A Glance - FNDDS Nutrient Values.xlsx"
)
# INGREDIENT_NUTRIENT_VALUES_PATH = (
#     "./2017-2018 FNDDS At A Glance - Ingredient Nutrient Values.xlsx"
# )

# %%
df_fndds_nutrient_values = pd.read_excel(FNDDS_NUTRIENT_VALUES_PATH, 0, skiprows=1)

# %%
df_fndds_nutrient_values.head()
# Out:
#    Food code           Main food description  WWEIA Category number  \
# 0   11000000                     Milk, human                   9602
# 1   11100000                       Milk, NFS                   1004
# 2   11111000                     Milk, whole                   1002
# 3   11111100         Milk, low sodium, whole                   1002
# 4   11111150  Milk, calcium fortified, whole                   1002
#
#   WWEIA Category description  Energy (kcal)  Protein (g)  Carbohydrate (g)  \
# 0                 Human milk             70         1.03              6.89
# 1          Milk, reduced fat             51         3.34              4.87
# 2                Milk, whole             60         3.28              4.67
# 3                Milk, whole             61         3.10              4.46
# 4                Milk, whole             60         3.28              4.67
#
#    Sugars, total\n(g)  Fiber, total dietary (g)  Total Fat (g)  ...  \
# 0                6.89                       0.0           4.38  ...
# 1                4.89                       0.0           1.99  ...
# 2                4.81                       0.0           3.20  ...
# 3                4.46                       0.0           3.46  ...
# 4                4.81                       0.0           3.20  ...
#
#    20:1\n(g)  22:1\n(g)  18:2\n(g)  18:3\n(g)  18:4\n(g)  20:4\n(g)  \
# 0      0.040        0.0      0.374      0.052        0.0      0.026
# 1      0.002        0.0      0.069      0.007        0.0      0.003
# 2      0.004        0.0      0.115      0.012        0.0      0.004
# 3      0.000        0.0      0.078      0.050        0.0      0.000
# 4      0.004        0.0      0.115      0.012        0.0      0.004
#
#    20:5 n-3\n(g)  22:5 n-3\n(g)  22:6 n-3\n(g)  Water\n(g)
# 0          0.000          0.000            0.0       87.50
# 1          0.000          0.001            0.0       89.04
# 2          0.001          0.002            0.0       88.10
# 3          0.000          0.000            0.0       88.20
# 4          0.001          0.002            0.0       88.10
#
# [5 rows x 69 columns]

# %%
pprint(set(df_fndds_nutrient_values["WWEIA Category description"].tolist()))
# Out:
# {'Apple juice',
#  'Apples',
#  'Baby food: cereals',
#  'Baby food: fruit',
#  'Baby food: meat and dinners',
#  'Baby food: snacks and sweets',
#  'Baby food: vegetable',
#  'Baby food: yogurt',
#  'Baby juice',
#  'Baby water',
#  'Bacon',
#  'Bagels and English muffins',
#  'Bananas',
#  'Bean, pea, legume dishes',
#  'Beans, peas, legumes',
#  'Beef, excludes ground',
#  'Beer',
#  'Biscuits, muffins, quick breads',
#  'Blueberries and other berries',
#  'Bottled water',
#  'Broccoli',
#  'Burgers (single code)',
#  'Burritos and tacos',
#  'Butter and animal fats',
#  'Cabbage',
#  'Cakes and pies',
#  'Candy containing chocolate',
#  'Candy not containing chocolate',
#  'Carrots',
#  'Cereal bars',
#  'Cheese',
#  'Cheese sandwiches (single code)',
#  'Chicken patties, nuggets and tenders',
#  'Chicken, whole pieces',
#  'Chicken/turkey sandwiches (single code)',
#  'Citrus fruits',
#  'Citrus juice',
#  'Coffee',
#  'Cold cuts and cured meats',
#  'Coleslaw, non-lettuce salads',
#  'Cookies and brownies',
#  'Corn',
#  'Cottage/ricotta cheese',
#  'Crackers, excludes saltines',
#  'Cream and cream substitutes',
#  'Cream cheese, sour cream, whipped cream',
#  'Diet soft drinks',
#  'Diet sport and energy drinks',
#  'Dips, gravies, other sauces',
#  'Doughnuts, sweet rolls, pastries',
#  'Dried fruits',
#  'Egg rolls, dumplings, sushi',
#  'Egg/breakfast sandwiches (single code)',
#  'Eggs and omelets',
#  'Enhanced or fortified water',
#  'Fish',
#  'Flavored milk, lowfat',
#  'Flavored milk, nonfat',
#  'Flavored milk, reduced fat',
#  'Flavored milk, whole',
#  'Flavored or carbonated water',
#  'Formula, prepared from concentrate',
#  'Formula, prepared from powder',
#  'Formula, ready-to-feed',
#  'Frankfurter sandwiches (single code)',
#  'Frankfurters',
#  'French fries and other fried white potatoes',
#  'Fried rice and lo/chow mein',
#  'Fried vegetables',
#  'Fruit drinks',
#  'Gelatins, ices, sorbets',
#  'Grapes',
#  'Grits and other cooked cereals',
#  'Ground beef',
#  'Human milk',
#  'Ice cream and frozen dairy desserts',
#  'Jams, syrups, toppings',
#  'Lamb, goat, game',
#  'Lettuce and lettuce salads',
#  'Liquor and cocktails',
#  'Liver and organ meats',
#  'Macaroni and cheese',
#  'Mango and papaya',
#  'Margarine',
#  'Mashed potatoes and white potato mixtures',
#  'Mayonnaise',
#  'Meat mixed dishes',
#  'Melons',
#  'Milk shakes and other dairy drinks',
#  'Milk substitutes',
#  'Milk, lowfat',
#  'Milk, nonfat',
#  'Milk, reduced fat',
#  'Milk, whole',
#  'Mustard and other condiments',
#  'Nachos',
#  'Not included in a food category',
#  'Nutrition bars',
#  'Nutritional beverages',
#  'Nuts and seeds',
#  'Oatmeal',
#  'Olives, pickles, pickled vegetables',
#  'Onions',
#  'Other Mexican mixed dishes',
#  'Other dark green vegetables',
#  'Other diet drinks',
#  'Other fruit juice',
#  'Other fruits and fruit salads',
#  'Other red and orange vegetables',
#  'Other sandwiches (single code)',
#  'Other starchy vegetables',
#  'Other vegetables and combinations',
#  'Pancakes, waffles, French toast',
#  'Pasta mixed dishes, excludes macaroni and cheese',
#  'Pasta sauces, tomato-based',
#  'Pasta, noodles, cooked grains',
#  'Peaches and nectarines',
#  'Peanut butter and jelly sandwiches (single code)',
#  'Pears',
#  'Pineapple',
#  'Pizza',
#  'Popcorn',
#  'Pork',
#  'Potato chips',
#  'Poultry mixed dishes',
#  'Pretzels/snack mix',
#  'Processed soy products',
#  'Protein and nutritional powders',
#  'Pudding',
#  'Ready-to-eat cereal, higher sugar (>21.2g/100g)',
#  'Ready-to-eat cereal, lower sugar (=<21.2g/100g)',
#  'Rice',
#  'Rice mixed dishes',
#  'Rolls and buns',
#  'Salad dressings and vegetable oils',
#  'Saltine crackers',
#  'Sausages',
#  'Seafood mixed dishes',
#  'Seafood sandwiches (single code)',
#  'Shellfish',
#  'Smoothies and grain drinks',
#  'Soft drinks',
#  'Soups',
#  'Soy-based condiments',
#  'Spinach',
#  'Sport and energy drinks',
#  'Stir-fry and soy-based sauce mixtures',
#  'Strawberries',
#  'String beans',
#  'Sugar substitutes',
#  'Sugars and honey',
#  'Tap water',
#  'Tea',
#  'Tomato-based condiments',
#  'Tomatoes',
#  'Tortilla, corn, other chips',
#  'Tortillas',
#  'Turkey, duck, other poultry',
#  'Turnovers and other grain-based items',
#  'Vegetable dishes',
#  'Vegetable juice',
#  'Vegetables on a sandwich',
#  'White potatoes, baked or boiled',
#  'Wine',
#  'Yeast breads',
#  'Yogurt, Greek',
#  'Yogurt, regular'}

# %%
def preprocess_wweia_category(value):
    if value == "Chicken, whole pieces":
        value = "Chicken in whole pieces"
    if value == "Chicken/turkey sandwiches (single code)":
        value = "Chicken sandwiches or turkey sandwiches"
    if value == "Coleslaw, non-lettuce salads":
        value = "Coleslaw or non-lettuce salads"
    if value == "Cottage/ricotta cheese":
        value = "Cottage cheese or ricotta cheese"
    if value == "Egg/breakfast sandwiches (single code)":
        value = "Egg sandwiches or breakfast sandwiches"
    if (
        value.__contains__("Flavored milk")
        or value.__contains__("Milk")
        or value.__contains__("Pasta sauces")
        or value.__contains__("White potatoes")
        or value.__contains__("Yogurt")
    ) and value.__contains__(","):
        tokens = value.split(",")
        value = tokens[-1] + " " + tokens[0]
    if value == "Fried rice and lo/chow mein":
        value = "Fried rice and lo mein or chow mein"

    value = value.replace(", excludes", " but excludes")
    value = value.replace(" (single code)", "")
    value = value.replace(",", " and")
    value = value.replace("/", " or ")
    value = value.lower()
    value = value.strip()

    return value


def preprocess_food_description(value):
    if (
        value
        == "Gyro sandwich (pita bread, beef, lamb, onion, condiments), with tomato and spread"
    ):
        value = (
            "Gyro sandwich with pita bread, beef, lamb, onion, tomato and condiments"
        )
    if value == "Dosa (Indian), plain":
        value = "Plain Indian Dosa"
    if value == "Dosa (Indian), with filling":
        value = "Indian Dosa with filling"
    if value == "Lefse (Norwegian)":
        value = "Norwegian Lefse"
    if value.__contains__("("):
        tokens = value.split("(")
        if tokens[-1].__contains__("%") or tokens[-1].__contains__("skim"):
            tokens.pop(-1)
        else:
            tokens[-1] = tokens[-1].replace(")", "")
            tokens[-1] = ", " + tokens[-1]
        value = "".join(tokens)
    value = value.replace("NFS", "Not Further Specified")
    value = value.replace("NS", "Not Specified")
    value = value.replace("/", " or ")
    value = value.lower()
    return value


def preprocess_nutrient_values(value):
    return value / 100


def clean_fndds_nutrient_values(df):
    maintain_columns = [
        "Main food description",
        "WWEIA Category description",
        "Energy (kcal)",
        "Protein (g)",
        "Carbohydrate (g)",
        "Total Fat (g)",
    ]
    new_df = df[maintain_columns]
    remove_categories = [
        "Not included in a food category",
        "Human milk",
        "Tap water",
        "Enhanced or fortified water",
        "Diet soft drinks",
        "Diet sport and energy drinks",
        "Flavored or carbonated water",
        "Smoothies and grain drinks",
        "Sport and energy drinks",
        "Protein and nutritional powders",
        "Nutritional beverages",
        "Nutrition bars",
        "Cereal bars",
        "Bottled water",
        "Milk shakes and other dairy drinks",
        "Fruit drinks",
        "Other fruit juice",
        "Other diet drinks",
        "Ready-to-eat cereal, higher sugar (>21.2g/100g)",
        "Ready-to-eat cereal, lower sugar (=<21.2g/100g)",
        "Coffee",
        "Citrus juice"
    ]
    new_df = new_df[
        ~new_df["WWEIA Category description"].isin(remove_categories)
        & ~new_df["WWEIA Category description"].str.contains("Baby")
        & ~new_df["WWEIA Category description"].str.contains("Formula")
    ]

    # Preprocessing remove noise from food category
    new_df["WWEIA Category description"] = new_df["WWEIA Category description"].apply(
        lambda x: preprocess_wweia_category(x)
    )

    # Preprocessing for main food description
    new_df["Main food description"] = new_df["Main food description"].apply(
        lambda x: preprocess_food_description(x)
    )

    new_df["Energy (kcal)"] = new_df["Energy (kcal)"].apply(
        lambda x: preprocess_nutrient_values(x)
    )
    new_df["Carbohydrate (g)"] = new_df["Carbohydrate (g)"].apply(
        lambda x: preprocess_nutrient_values(x)
    )
    new_df["Protein (g)"] = new_df["Protein (g)"].apply(
        lambda x: preprocess_nutrient_values(x)
    )
    new_df["Total Fat (g)"] = new_df["Total Fat (g)"].apply(
        lambda x: preprocess_nutrient_values(x)
    )

    return new_df

# %%
df_fndds_nutrient_values = clean_fndds_nutrient_values(df_fndds_nutrient_values)

# %%
cleaned_categories = set(
    df_fndds_nutrient_values["WWEIA Category description"].tolist()
)
cleaned_categories
# Out:
# {'apple juice',
#  'apples',
#  'bacon',
#  'bagels and english muffins',
#  'baked or boiled white potatoes',
#  'bananas',
#  'bean and pea and legume dishes',
#  'beans and peas and legumes',
#  'beef but excludes ground',
#  'beer',
#  'biscuits and muffins and quick breads',
#  'blueberries and other berries',
#  'broccoli',
#  'burgers',
#  'burritos and tacos',
#  'butter and animal fats',
#  'cabbage',
#  'cakes and pies',
#  'candy containing chocolate',
#  'candy not containing chocolate',
#  'carrots',
#  'cheese',
#  'cheese sandwiches',
#  'chicken in whole pieces',
#  'chicken patties and nuggets and tenders',
#  'chicken sandwiches or turkey sandwiches',
#  'citrus fruits',
#  'cold cuts and cured meats',
#  'coleslaw or non-lettuce salads',
#  'cookies and brownies',
#  'corn',
#  'cottage cheese or ricotta cheese',
#  'crackers but excludes saltines',
#  'cream and cream substitutes',
#  'cream cheese and sour cream and whipped cream',
#  'dips and gravies and other sauces',
#  'doughnuts and sweet rolls and pastries',
#  'dried fruits',
#  'egg rolls and dumplings and sushi',
#  'egg sandwiches or breakfast sandwiches',
#  'eggs and omelets',
#  'fish',
#  'frankfurter sandwiches',
#  'frankfurters',
#  'french fries and other fried white potatoes',
#  'fried rice and lo mein or chow mein',
#  'fried vegetables',
#  'gelatins and ices and sorbets',
#  'grapes',
#  'greek yogurt',
#  'grits and other cooked cereals',
#  'ground beef',
#  'ice cream and frozen dairy desserts',
#  'jams and syrups and toppings',
#  'lamb and goat and game',
#  'lettuce and lettuce salads',
#  'liquor and cocktails',
#  'liver and organ meats',
#  'lowfat flavored milk',
#  'lowfat milk',
#  'macaroni and cheese',
#  'mango and papaya',
#  'margarine',
#  'mashed potatoes and white potato mixtures',
#  'mayonnaise',
#  'meat mixed dishes',
#  'melons',
#  'milk substitutes',
#  'mustard and other condiments',
#  'nachos',
#  'nonfat flavored milk',
#  'nonfat milk',
#  'nuts and seeds',
#  'oatmeal',
#  'olives and pickles and pickled vegetables',
#  'onions',
#  'other dark green vegetables',
#  'other fruits and fruit salads',
#  'other mexican mixed dishes',
#  'other red and orange vegetables',
#  'other sandwiches',
#  'other starchy vegetables',
#  'other vegetables and combinations',
#  'pancakes and waffles and french toast',
#  'pasta and noodles and cooked grains',
#  'pasta mixed dishes but excludes macaroni and cheese',
#  'peaches and nectarines',
#  'peanut butter and jelly sandwiches',
#  'pears',
#  'pineapple',
#  'pizza',
#  'popcorn',
#  'pork',
#  'potato chips',
#  'poultry mixed dishes',
#  'pretzels or snack mix',
#  'processed soy products',
#  'pudding',
#  'reduced fat flavored milk',
#  'reduced fat milk',
#  'regular yogurt',
#  'rice',
#  'rice mixed dishes',
#  'rolls and buns',
#  'salad dressings and vegetable oils',
#  'saltine crackers',
#  'sausages',
#  'seafood mixed dishes',
#  'seafood sandwiches',
#  'shellfish',
#  'soft drinks',
#  'soups',
#  'soy-based condiments',
#  'spinach',
#  'stir-fry and soy-based sauce mixtures',
#  'strawberries',
#  'string beans',
#  'sugar substitutes',
#  'sugars and honey',
#  'tea',
#  'tomato-based condiments',
#  'tomato-based pasta sauces',
#  'tomatoes',
#  'tortilla and corn and other chips',
#  'tortillas',
#  'turkey and duck and other poultry',
#  'turnovers and other grain-based items',
#  'vegetable dishes',
#  'vegetable juice',
#  'vegetables on a sandwich',
#  'whole flavored milk',
#  'whole milk',
#  'wine',
#  'yeast breads'}

# %%
pprint(
    df_fndds_nutrient_values[
        df_fndds_nutrient_values["WWEIA Category description"].str.contains("\t")
    ]["Main food description"].tolist()
)
# Out:
# []

# %%
df_fndds_nutrient_values[
    df_fndds_nutrient_values["Main food description"].str.contains("indian")
    | df_fndds_nutrient_values["Main food description"].str.contains("nesquik")
]
# Out:
#                                   Main food description  \
# 103   chocolate milk, ready to drink, low fat , nesquik
# 104   chocolate milk, ready to drink, fat free , nes...
# 105   chocolate milk, ready to drink, low fat, no su...
# 124   chocolate milk, made from dry mix, not specifi...
# 125   chocolate milk, made from dry mix with whole m...
# 126   chocolate milk, made from dry mix with reduced...
# 127   chocolate milk, made from dry mix with low fat...
# 128   chocolate milk, made from dry mix with fat fre...
# 129   chocolate milk, made from dry mix with non-dai...
# 130   chocolate milk, made from no sugar added dry m...
# 131   chocolate milk, made from no sugar added dry m...
# 132   chocolate milk, made from no sugar added dry m...
# 133   chocolate milk, made from no sugar added dry m...
# 134   chocolate milk, made from no sugar added dry m...
# 135   chocolate milk, made from no sugar added dry m...
# 471                               firni, indian pudding
# 485                      barfi or burfi, indian dessert
# 3128                             naan, indian flatbread
# 4008                                  plain indian dosa
# 5007                        upma, indian breakfast dish
# 5008                           indian dosa with filling
# 6565            ladoo, round ball, asian-indian dessert
#
#                  WWEIA Category description  Energy (kcal)  Protein (g)  \
# 103                    lowfat flavored milk           0.64       0.0346
# 104                    nonfat flavored milk           0.67       0.0339
# 105                    lowfat flavored milk           0.64       0.0346
# 124               reduced fat flavored milk           0.72       0.0341
# 125                     whole flavored milk           0.81       0.0336
# 126               reduced fat flavored milk           0.72       0.0342
# 127                    lowfat flavored milk           0.65       0.0345
# 128                    nonfat flavored milk           0.57       0.0350
# 129                        milk substitutes           0.59       0.0168
# 130               reduced fat flavored milk           0.63       0.0359
# 131                     whole flavored milk           0.73       0.0353
# 132               reduced fat flavored milk           0.63       0.0360
# 133                    lowfat flavored milk           0.56       0.0363
# 134                    nonfat flavored milk           0.48       0.0367
# 135                        milk substitutes           0.50       0.0182
# 471                                 pudding           1.41       0.0358
# 485                                 pudding           2.77       0.0541
# 3128                           yeast breads           3.11       0.1109
# 4008  pancakes and waffles and french toast           2.10       0.0570
# 5007         grits and other cooked cereals           0.86       0.0198
# 5008  turnovers and other grain-based items           1.84       0.0546
# 6565         candy not containing chocolate           4.01       0.0692
#
#       Carbohydrate (g)  Total Fat (g)
# 103             0.1015         0.0111
# 104             0.1346         0.0000
# 105             0.1015         0.0111
# 124             0.1013         0.0201
# 125             0.0994         0.0314
# 126             0.1016         0.0192
# 127             0.1043         0.0103
# 128             0.1014         0.0022
# 129             0.1032         0.0127
# 130             0.0761         0.0210
# 131             0.0742         0.0326
# 132             0.0764         0.0201
# 133             0.0791         0.0110
# 134             0.0763         0.0027
# 135             0.0781         0.0134
# 471             0.2517         0.0310
# 485             0.4046         0.1134
# 3128            0.5023         0.0728
# 4008            0.3704         0.0405
# 5007            0.1381         0.0264
# 5008            0.3080         0.0427
# 6565            0.4674         0.2198

# %%
with open("./cleaned_food_category.txt", "w") as file:
    file.writelines(sent + "\n" for sent in cleaned_categories)

# %%
df_fndds_nutrient_values.to_csv(
    "./cleaned_fndds_nutrient_values.csv", sep="\t", index=False, float_format = "%.4f"
)

# %%
df_nutrition5k_ingredients = pd.read_csv(
    "../nutrition5k/metadata/ingredients_metadata.csv"
)

# %%
df_nutrition5k_ingredients

# %% [markdown]
# ## Removed

# %%
df_fndds_food_category = df_fndds_nutrient_values.loc[
    :, ["Main food description", "WWEIA Category description"]
]

# %%
df_fndds_food_category.loc[:, "matched"] = 1

# %%
all_category = set(df_fndds_nutrient_values["WWEIA Category description"].tolist())
all_food = set(df_fndds_nutrient_values["Main food description"].tolist())

for food in all_food:
    take_out = df_fndds_food_category[
        df_fndds_food_category["Main food description"] == food
    ]["WWEIA Category description"].values[0]
    all_category.remove(take_out)
    duplication = [food] * len(all_category)
    new_rows = [
        [food, category, 0] for food, category in zip(duplication, all_category)
    ]
    concat_df = pd.DataFrame(
        new_rows,
        columns=["Main food description", "WWEIA Category description", "matched"],
    )
    df_fndds_food_category = pd.concat(
        [df_fndds_food_category, concat_df], ignore_index=True
    )
    all_category.add(take_out)

# %%
df_fndds_food_category

# %%
df_fndds_food_category[df_fndds_food_category["Main food description"] == "Milk, NFS"]

# %%
# df_fndds_food_category.to_csv("./USDA-FNDDS/FNDDS_FoodtoCategory_Corpus.csv",sep="\t",header=False,index=False)

# %%
def clean_ingredient_nutrient_values(df):
    maintain_columns = [
        "Ingredient description",
        "Nutrient description",
        "Nutrient value",
    ]
    new_df = df[maintain_columns]
    maintain_nutrients = ["Energy", "Carbohydrate", "Protein", "Total Fat"]
    remove_ingredients = ["Vitamin D as ingredient"]
    new_df = new_df[
        new_df["Nutrient description"].isin(maintain_nutrients)
        & ~new_df["Ingredient description"].isin(remove_ingredients)
        & ~new_df["Ingredient description"].str.contains("REDUCED SODIUM")
    ]
    new_df = new_df.pivot(
        index="Ingredient description",
        columns="Nutrient description",
        values="Nutrient value",
    )
    new_df = new_df.reset_index()
    new_df.columns.rename("", True)
    filtered_ingredient = [
        "Alcoholic beverage",
        "Apple juice",
        "Babyfood",
        "Beverages",
        "Candies",
        "Cereals ready-to-eat",
        "Chewing gum",
        "Child formula",
        "Fluid replacement",
        "Formulated Bar",
        "Formulated bar",
        "Granola bar",
        "HOT POCKETS",
        "Infant",
        "LEAN POCKETS",
        "Nutritional supplement for people with diabetes" "Orange juice",
        "Pineapple juice",
        "Protein supplement",
        "RICE-A-RONI",
        "Rice and Wheat cereal bar",
        "SCHIFF",
        "School Lunch",
        "Snacks",
        "Snack",
        "Shake",
        "Tangerine juice",
        "Water",
    ]

    for filter_ingredient in filtered_ingredient:
        new_df = new_df[
            ~new_df["Ingredient description"].str.contains(filter_ingredient)
        ]
    return new_df
